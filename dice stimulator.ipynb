# %%
import random
print("This is the Dice stimulator")

x="y"
while x=="y":
    number = random.randint(1, 6)
    print(number)
    if number == 1:
        print("--------")
        print("|      |")
        print("|   0  |")
        print("|      |")
        print("--------")
    
    
    if number == 2:
        print("--------")
        print("|   0  |")
        print("|      |")
        print("|   0  |")
        print("--------")

    if number == 3:
        print("--------")
        print("|     0|")
        print("|   0  |")
        print("| 0    |")
        print("--------")
    
    if number == 4:
        print("--------")
        print("| 0  0 |")
        print("|      |")
        print("| 0  0 |")
        print("--------")


    if number == 5:
        print("--------")
        print("| 0   0|")
        print("|   0  |")
        print("| 0   0|")
        print("--------")

    if number == 6:
        print("--------")
        print("| 0   0|")
        print("| 0   0|")
        print("| 0   0|")
        print("--------")
        
    x = input("Press y to roll again: ")
# Out:
# This is the Dice stimulator
# 3
# --------
# |     0|
# |   0  |
# | 0    |
# --------
# Press y to roll again: y
# 4
# --------
# | 0  0 |
# |      |
# | 0  0 |
# --------
# Press y to roll again: y
# 1
# --------
# |      |
# |   0  |
# |      |
# --------
# Press y to roll again: y
# 3
# --------
# |     0|
# |   0  |
# | 0    |
# --------
# Press y to roll again: y
# 4
# --------
# | 0  0 |
# |      |
# | 0  0 |
# --------
# Press y to roll again: y
# 3
# --------
# |     0|
# |   0  |
# | 0    |
# --------
# Press y to roll again: n
